# %%
import pandas as pd
import numpy as np

# %%
names = ['Olga', 'Andrew', 'Brian', 'Telulah', 'Nicole', 'Tilda']
ages = [29, 21, 45, 23, 39, 46]
married = [False, True, False, True, False, True]

# %%
df = pd.DataFrame({'names': names , 'age': ages, 'married': married})

# %%
df
# Out:
#      names  age  married
# 0     Olga   29    False
# 1   Andrew   21     True
# 2    Brian   45    False
# 3  Telulah   23     True
# 4   Nicole   39    False
# 5    Tilda   46     True

# %%
df.iloc[2, 0]
# Out:
# 'Brian'

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (6, 3)

# %%
df.names
# Out:
# 0       Olga
# 1     Andrew
# 2      Brian
# 3    Telulah
# 4     Nicole
# 5      Tilda
# Name: names, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      names  age  married
# 0     Olga   29    False
# 1   Andrew   21     True
# 2    Brian   45    False
# 3  Telulah   23     True
# 4   Nicole   39    False
# 5    Tilda   46     True>

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   names    6 non-null      object
#  1   age      6 non-null      int64
#  2   married  6 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 230.0+ bytes

# %%
df.info(memory_usage = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   names    6 non-null      object
#  1   age      6 non-null      int64
#  2   married  6 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 230.0+ bytes

# %% [markdown]
# # Creating a dataframe

# %%
dataurl = 'https://andybek.com/pandas-nutrition'

# %%
nutrition = pd.read_csv(dataurl)

# %%
nutrition.head(2)
# Out:
#    Unnamed: 0          name serving_size  calories total_fat saturated_fat  \
# 0           0    Cornstarch        100 g       381      0.1g           NaN
# 1           1  Nuts, pecans        100 g       691       72g          6.2g
#
#   cholesterol   sodium  choline     folate  ...      fat  \
# 0           0  9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0  0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
#
#   caffeine theobromine   water
# 0  0.00 mg     0.00 mg  8.32 g
# 1  0.00 mg     0.00 mg  3.52 g
#
# [2 rows x 77 columns]

# %%
nutrition.drop('Unnamed: 0', axis = 1)
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
nutrition.set_index('Unnamed: 0')
# Out:
#                                                          name serving_size  \
# Unnamed: 0
# 0                                                  Cornstarch        100 g
# 1                                                Nuts, pecans        100 g
# 2                                               Eggplant, raw        100 g
# 3                                              Teff, uncooked        100 g
# 4                                             Sherbet, orange        100 g
# ...                                                       ...          ...
# 8784        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785        Lamb, cooked, separable lean only, composite o...        100 g
# 8786        Lamb, raw, separable lean and fat, composite o...        100 g
# 8787        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788        Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
# ...

# %%
nutrition.head(2)
# Out:
#    Unnamed: 0          name serving_size  calories total_fat saturated_fat  \
# 0           0    Cornstarch        100 g       381      0.1g           NaN
# 1           1  Nuts, pecans        100 g       691       72g          6.2g
#
#   cholesterol   sodium  choline     folate  ...      fat  \
# 0           0  9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0  0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
#
#   caffeine theobromine   water
# 0  0.00 mg     0.00 mg  8.32 g
# 1  0.00 mg     0.00 mg  3.52 g
#
# [2 rows x 77 columns]

# %%
nutrition = pd.read_csv(dataurl, index_col = [0])

# %%
nutrition.head(3)
# Out:
#             name serving_size  calories total_fat saturated_fat cholesterol  \
# 0     Cornstarch        100 g       381      0.1g           NaN           0
# 1   Nuts, pecans        100 g       691       72g          6.2g           0
# 2  Eggplant, raw        100 g        25      0.2g           NaN           0
#
#     sodium  choline     folate folic_acid  ...      fat saturated_fatty_acids  \
# 0  9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g               0.009 g
# 1  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g               6.180 g
# 2  2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g               0.034 g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                     0.016 g                     0.025 g
# 1                    40.801 g                    21.614 g
# 2                     0.016 g                     0.076 g
#
#   fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# ...

# %%
nutrition.sample()
# Out:
#                           name serving_size  calories total_fat saturated_fat  \
# 1170  Fungi, dried, Cloud ears        100 g       284      0.7g           NaN
#
#      cholesterol    sodium choline     folate folic_acid  ...     fat  \
# 1170           0  35.00 mg       0  38.00 mcg   0.00 mcg  ...  0.73 g
#
#      saturated_fatty_acids monounsaturated_fatty_acids  \
# 1170                     0                           0
#
#      polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 1170                           0                 0.00 mg       0  2.21 g
#
#      caffeine theobromine    water
# 1170        0           0  14.80 g
#
# [1 rows x 76 columns]

# %% [markdown]
# # Dataframe Axes

# %%
nutrition.head(3)
# Out:
#             name serving_size  calories total_fat saturated_fat cholesterol  \
# 0     Cornstarch        100 g       381      0.1g           NaN           0
# 1   Nuts, pecans        100 g       691       72g          6.2g           0
# 2  Eggplant, raw        100 g        25      0.2g           NaN           0
#
#     sodium  choline     folate folic_acid  ...      fat saturated_fatty_acids  \
# 0  9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g               0.009 g
# 1  0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g               6.180 g
# 2  2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g               0.034 g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                     0.016 g                     0.025 g
# 1                    40.801 g                    21.614 g
# 2                     0.016 g                     0.076 g
#
#   fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# ...

# %%
nutrition.axes[0][3]
# Out:
# 3

# %%
nutrition.index[1]
# Out:
# 1

# %%
nutrition.columns[50]
# Out:
# 'phenylalanine'

# %% [markdown]
# # Changing the index

# %%
nutrition.set_index('name', inplace = True)

# %%
nutrition.head(3)
# Out:
#               serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch           100 g       381      0.1g           NaN           0
# Nuts, pecans         100 g       691       72g          6.2g           0
# Eggplant, raw        100 g        25      0.2g           NaN           0
#
#                 sodium  choline     folate folic_acid    niacin  ...      fat  \
# name                                                             ...
# Cornstarch     9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...   0.05 g
# Nuts, pecans   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...  71.97 g
# Eggplant, raw  2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...   0.18 g
#
#               saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                  0.009 g                     0.016 g
# Nuts, pecans                6.180 g                    40.801 g
# Eggplant, raw               0.034 g                     0.016 g
#
# ...

# %% [markdown]
# # Extracting from dataframe by label

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutrition.loc['Eggplant, raw']
# Out:
# serving_size       100 g
# calories              25
# total_fat           0.2g
# saturated_fat        NaN
# cholesterol            0
#                   ...
# alcohol            0.0 g
# ash               0.66 g
# caffeine         0.00 mg
# theobromine      0.00 mg
# water            92.30 g
# Name: Eggplant, raw, Length: 75, dtype: object

# %%
nutrition.loc['Eggplant, raw']['calories']
# Out:
# 25

# %%
nutrition.loc['Eggplant, raw','calories']
# Out:
# 25

# %%
nutrition.loc['Nuts, pecans':'Teff, uncooked', 'cholesterol':'niacin']
# Out:
#                cholesterol    sodium  choline     folate folic_acid    niacin
# name
# Nuts, pecans             0   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg
# Eggplant, raw            0   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg
# Teff, uncooked           0  12.00 mg  13.1 mg          0          0  3.363 mg

# %%
nutrition.loc[
              ['Nuts, pecans'],
              ['sodium', 'choline',	'folate', 'niacin']
]
# Out:
#                sodium  choline     folate    niacin
# name
# Nuts, pecans  0.00 mg  40.5 mg  22.00 mcg  1.167 mg

# %% [markdown]
# # Dataframe extraction by position

# %%
nutrition.iloc[4]
# Out:
# serving_size       100 g
# calories             144
# total_fat             2g
# saturated_fat       1.2g
# cholesterol          1mg
#                   ...
# alcohol            0.0 g
# ash               0.40 g
# caffeine         0.00 mg
# theobromine      0.00 mg
# water            66.10 g
# Name: Sherbet, orange, Length: 75, dtype: object

# %%
nutrition.iloc[4:6, 3:14]
# Out:
#                  saturated_fat cholesterol    sodium  choline     folate  \
# name
# Sherbet, orange           1.2g         1mg  46.00 mg   7.7 mg   4.00 mcg
# Cauliflower, raw          0.1g           0  30.00 mg  44.3 mg  57.00 mcg
#
#                  folic_acid    niacin pantothenic_acid riboflavin   thiamin  \
# name
# Sherbet, orange    0.00 mcg  0.063 mg         0.224 mg   0.097 mg  0.027 mg
# Cauliflower, raw   0.00 mcg  0.507 mg         0.667 mg   0.060 mg  0.050 mg
#
#                  vitamin_a
# name
# Sherbet, orange   46.00 IU
# Cauliflower, raw   0.00 IU

# %%
nutrition.iloc[
              [2, 3, 6, 8, 20],
              3
]
# Out:
# name
# Eggplant, raw              NaN
# Teff, uncooked            0.4g
# Taro leaves, raw          0.2g
# Cheese, camembert          15g
# Grapes, raw, muscadine     NaN
# Name: saturated_fat, dtype: object

# %%
nutrition.iloc[
              [2, 3, 6, 8, 20],
              3:9
]
# Out:
#                        saturated_fat cholesterol     sodium  choline  \
# name
# Eggplant, raw                    NaN           0    2.00 mg   6.9 mg
# Teff, uncooked                  0.4g           0   12.00 mg  13.1 mg
# Taro leaves, raw                0.2g           0    3.00 mg  12.8 mg
# Cheese, camembert                15g        72mg  842.00 mg  15.4 mg
# Grapes, raw, muscadine           NaN           0    1.00 mg        0
#
#                             folate folic_acid
# name
# Eggplant, raw            22.00 mcg   0.00 mcg
# Teff, uncooked                   0          0
# Taro leaves, raw        126.00 mcg   0.00 mcg
# Cheese, camembert        62.00 mcg   0.00 mcg
# Grapes, raw, muscadine    2.00 mcg          0

# %% [markdown]
# # Extracting a single value from dataframe

# %%
nutrition.iloc[8, 6]
# Out:
# '15.4 mg'

# %%
nutrition.loc['Cheese, camembert', 'folate']
# Out:
# '62.00 mcg'

# %%
nutrition.at['Cheese, camembert', 'folate']
# Out:
# '62.00 mcg'

# %%
nutrition.iat[8, 6]
# Out:
# '15.4 mg'

# %% [markdown]
# # Skill Challenge 1

# %%
nutri_mini = nutrition.sample(10)

# %%
nutri_mini
# Out:
#                                                    serving_size  calories  \
# name
# Cabbage, without salt, drained, boiled, cooked,...        100 g        12
# Fast foods, with tartar sauce and cheese, fish ...        100 g       279
# Beef, grilled, cooked, all grades, trimmed to 0...        100 g       211
# Beef, roasted, cooked, choice, trimmed to 1/8" ...        100 g       240
# CAMPBELL'S, V8 100% Vegetable Juice                       100 g        21
# Babyfood, junior, applesauce, fruit                       100 g        37
# Creamy dressing, cholesterol-free, reduced calo...        100 g       140
# Peanut butter with omega-3, creamy                        100 g       608
# Squash, without salt, or baked, drained, boiled...        100 g        27
# Pie crust, unenriched, ready-to-bake, frozen, s...        100 g       457
#
#                                                    total_fat saturated_fat  \
# name
# ...

# %%
nutri_mini.loc[
    :,
    ['total_fat', 'cholesterol']
]
# Out:
#                                                    total_fat cholesterol
# name
# Cabbage, without salt, drained, boiled, cooked,...      0.2g           0
# Fast foods, with tartar sauce and cheese, fish ...       15g        37mg
# Beef, grilled, cooked, all grades, trimmed to 0...      8.9g        93mg
# Beef, roasted, cooked, choice, trimmed to 1/8" ...       15g        83mg
# CAMPBELL'S, V8 100% Vegetable Juice                       0g           0
# Babyfood, junior, applesauce, fruit                       0g           0
# Creamy dressing, cholesterol-free, reduced calo...        8g           0
# Peanut butter with omega-3, creamy                       54g           0
# Squash, without salt, or baked, drained, boiled...      0.3g           0
# Pie crust, unenriched, ready-to-bake, frozen, s...       29g           0

# %%
vitamin_b12_loc = nutri_mini.columns.get_loc('vitamin_b12')
vitamin_b12_loc
# Out:
# 20

# %%
nutri_mini.iloc[0:3, vitamin_b12_loc:]
# Out:
#                                                    vitamin_b12 vitamin_b6  \
# name
# Cabbage, without salt, drained, boiled, cooked,...    0.00 mcg   0.166 mg
# Fast foods, with tartar sauce and cheese, fish ...    0.59 mcg   0.060 mg
# Beef, grilled, cooked, all grades, trimmed to 0...    4.10 mcg   0.687 mg
#
#                                                    vitamin_c vitamin_d  \
# name
# Cabbage, without salt, drained, boiled, cooked,...   26.0 mg   0.00 IU
# Fast foods, with tartar sauce and cheese, fish ...    1.5 mg  37.00 IU
# Beef, grilled, cooked, all grades, trimmed to 0...    0.0 mg   3.00 IU
#
#                                                    vitamin_e tocopherol_alpha  \
# name
# Cabbage, without salt, drained, boiled, cooked,...   0.09 mg          0.09 mg
# Fast foods, with tartar sauce and cheese, fish ...   1.00 mg          1.00 mg
# Beef, grilled, cooked, all grades, trimmed to 0...   0.14 mg          0.14 mg
#
# ...

# %%
nutri_mini.at['Fast foods, with tartar sauce and cheese, fish sandwich', 'vitamin_b6']
# Out:
# '0.060 mg'

# %% [markdown]
# # astype() Method

# %%
temp = pd.DataFrame(
    {
        'age': [12, 13, 14, 15, 16],
        'weight': [41.1, 34.5, 84.2, 90.1, 88.0],
        'height': ['1.72', '1.74', '1.91', '1.54', '0.99']
    }
)

# %%
temp
# Out:
#    age  weight height
# 0   12    41.1   1.72
# 1   13    34.5   1.74
# 2   14    84.2   1.91
# 3   15    90.1   1.54
# 4   16    88.0   0.99

# %%
temp = temp.astype(float)

# %%
temp
# Out:
#     age  weight  height
# 0  12.0    41.1    1.72
# 1  13.0    34.5    1.74
# 2  14.0    84.2    1.91
# 3  15.0    90.1    1.54
# 4  16.0    88.0    0.99

# %%
temp.astype(
    {
        'age': np.int16,
        'height': np.int16
    }
)
# Out:
#    age  weight  height
# 0   12    41.1       1
# 1   13    34.5       1
# 2   14    84.2       1
# 3   15    90.1       1
# 4   16    88.0       0

# %%
temp
# Out:
#     age  weight  height
# 0  12.0    41.1    1.72
# 1  13.0    34.5    1.74
# 2  14.0    84.2    1.91
# 3  15.0    90.1    1.54
# 4  16.0    88.0    0.99

# %% [markdown]
# # Dataframe replace() + A glimpse at regex

# %%
dfm = nutrition.iloc[:6, :1]

# %%
dfm.replace(to_replace= '100 g', value = 100)
# Out:
#                   serving_size
# name
# Cornstarch                 100
# Nuts, pecans               100
# Eggplant, raw              100
# Teff, uncooked             100
# Sherbet, orange            100
# Cauliflower, raw           100

# %%
# regex -> regular expression

# %%
dfm.replace('\sg', '', regex = True).astype(int)
# Out:
#                   serving_size
# name
# Cornstarch                 100
# Nuts, pecans               100
# Eggplant, raw              100
# Teff, uncooked             100
# Sherbet, orange            100
# Cauliflower, raw           100

# %% [markdown]
# # Rename method

# %%
df
# Out:
#      names  age  married
# 0     Olga   29    False
# 1   Andrew   21     True
# 2    Brian   45    False
# 3  Telulah   23     True
# 4   Nicole   39    False
# 5    Tilda   46     True

# %%
df.rename(
    columns = {'age':'Age', 'married': 'Marital Status'},
    index = {0:'O)', 1:'1)'},
    inplace = False
)
# Out:
#       names  Age  Marital Status
# O)     Olga   29           False
# 1)   Andrew   21            True
# 2     Brian   45           False
# 3   Telulah   23            True
# 4    Nicole   39           False
# 5     Tilda   46            True

# %%
df.rename(mapper = {'age': 'Age'}, axis = 1)
# Out:
#      names  Age  married
# 0     Olga   29    False
# 1   Andrew   21     True
# 2    Brian   45    False
# 3  Telulah   23     True
# 4   Nicole   39    False
# 5    Tilda   46     True

# %% [markdown]
# # Dropna method

# %%
df
# Out:
#      names  age  married
# 0     Olga   29    False
# 1   Andrew   21     True
# 2    Brian   45    False
# 3  Telulah   23     True
# 4   Nicole   39    False
# 5    Tilda   46     True

# %%
df.loc[1, :] = np.nan

# %%
df
# Out:
#      names   age married
# 0     Olga  29.0   False
# 1      NaN   NaN     NaN
# 2    Brian  45.0   False
# 3  Telulah  23.0    True
# 4   Nicole  39.0   False
# 5    Tilda  46.0    True

# %%
df.dropna(how = 'any', axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5]

# %%
df.dropna(how = 'any', axis = 0)
# Out:
#      names   age married
# 0     Olga  29.0   False
# 2    Brian  45.0   False
# 3  Telulah  23.0    True
# 4   Nicole  39.0   False
# 5    Tilda  46.0    True

# %%
df.dropna(how = 'all', axis = 0)
# Out:
#      names   age married
# 0     Olga  29.0   False
# 2    Brian  45.0   False
# 3  Telulah  23.0    True
# 4   Nicole  39.0   False
# 5    Tilda  46.0    True

# %% [markdown]
# # Creating units dataframe

# %%
units = nutrition.astype(str).replace('[^a-zA-Z]', '', regex = True)

# %%
unit = units.mode()

# %%
unit
# Out:
#   serving_size calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g                  g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 75 columns]

# %%
for u in unit:
  print(u)
print(unit.shape)
# Out:
# serving_size
# calories
# total_fat
# saturated_fat
# cholesterol
# sodium
# choline
# folate
# folic_acid
# niacin
# pantothenic_acid
# riboflavin
# thiamin
# vitamin_a
# vitamin_a_rae
# carotene_alpha
# carotene_beta
# cryptoxanthin_beta
# lutein_zeaxanthin
# lucopene
# vitamin_b12
# vitamin_b6
# vitamin_c
# vitamin_d
# vitamin_e
# tocopherol_alpha
# vitamin_k
# calcium
# copper
# irom
# magnesium
# manganese
# phosphorous
# potassium
# selenium
# zink
# protein
# alanine
# arginine
# aspartic_acid
# cystine
# glutamic_acid
# glycine
# histidine
# hydroxyproline
# isoleucine
# leucine
# lysine
# methionine
# phenylalanine
# proline
# serine
# threonine
# tryptophan
# tyrosine
# valine
# carbohydrate
# fiber
# sugars
# fructose
# galactose
# glucose
# lactose
# maltose
# sucrose
# fat
# saturated_fatty_acids
# monounsaturated_fatty_acids
# polyunsaturated_fatty_acids
# fatty_acids_total_trans
# alcohol
# ash
# caffeine
# theobromine
# water
# (1, 75)

# %%
for u in unit:
  print(u, unit[u].at[0])
print(unit.shape)
# Out:
# serving_size g
# calories
# total_fat g
# saturated_fat g
# cholesterol mg
# sodium mg
# choline mg
# folate mcg
# folic_acid mcg
# niacin mg
# pantothenic_acid mg
# riboflavin mg
# thiamin mg
# vitamin_a IU
# vitamin_a_rae mcg
# carotene_alpha mcg
# carotene_beta mcg
# cryptoxanthin_beta mcg
# lutein_zeaxanthin mcg
# lucopene
# vitamin_b12 mcg
# vitamin_b6 mg
# vitamin_c mg
# vitamin_d IU
# vitamin_e mg
# tocopherol_alpha mg
# vitamin_k mcg
# calcium mg
# copper mg
# irom mg
# magnesium mg
# manganese mg
# phosphorous mg
# potassium mg
# selenium mcg
# zink mg
# protein g
# alanine g
# arginine g
# aspartic_acid g
# cystine g
# glutamic_acid g
# glycine g
# histidine g
# hydroxyproline
# isoleucine g
# leucine g
# lysine g
# methionine g
# phenylalanine g
# proline g
# serine g
# threonine g
# tryptophan g
# tyrosine g
# valine g
# carbohydrate g
# fiber g
# sugars g
# fructose
# galactose
# glucose
# lactose
# maltose
# sucrose
# fat g
# saturated_fatty_acids g
# ...

# %%
unit = unit.replace('', np.nan)
unit
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g       NaN         g             g          mg     mg      mg
#
#   folate folic_acid niacin  ... fat saturated_fatty_acids  \
# 0    mcg        mcg     mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine  water
# 0                      mg       g   g       mg          mg      g
#
# [1 rows x 75 columns]

# %%
unit = unit.dropna(axis = 1)
unit
# Out:
#   serving_size total_fat saturated_fat cholesterol sodium choline folate  \
# 0            g         g             g          mg     mg      mg    mcg
#
#   folic_acid niacin pantothenic_acid  ... fat saturated_fatty_acids  \
# 0        mcg     mg               mg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 66 columns]

# %%
for u in unit:
  print(unit[u].at[0])
# Out:
# g
# g
# g
# mg
# mg
# mg
# mcg
# mcg
# mg
# mg
# mg
# mg
# IU
# mcg
# mcg
# mcg
# mcg
# mcg
# mcg
# mg
# mg
# IU
# mg
# mg
# mcg
# mg
# mg
# mg
# mg
# mg
# mg
# mg
# mcg
# mg
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# mg
# g
# g
# mg
# mg
# g

# %%
mapper = {
    k: k + '_' + unit[k].at[0] for k in unit
}

# %%
mapper
# Out:
# {'serving_size': 'serving_size_g',
#  'total_fat': 'total_fat_g',
#  'saturated_fat': 'saturated_fat_g',
#  'cholesterol': 'cholesterol_mg',
#  'sodium': 'sodium_mg',
#  'choline': 'choline_mg',
#  'folate': 'folate_mcg',
#  'folic_acid': 'folic_acid_mcg',
#  'niacin': 'niacin_mg',
#  'pantothenic_acid': 'pantothenic_acid_mg',
#  'riboflavin': 'riboflavin_mg',
#  'thiamin': 'thiamin_mg',
#  'vitamin_a': 'vitamin_a_IU',
#  'vitamin_a_rae': 'vitamin_a_rae_mcg',
#  'carotene_alpha': 'carotene_alpha_mcg',
#  'carotene_beta': 'carotene_beta_mcg',
#  'cryptoxanthin_beta': 'cryptoxanthin_beta_mcg',
#  'lutein_zeaxanthin': 'lutein_zeaxanthin_mcg',
#  'vitamin_b12': 'vitamin_b12_mcg',
#  'vitamin_b6': 'vitamin_b6_mg',
#  'vitamin_c': 'vitamin_c_mg',
#  'vitamin_d': 'vitamin_d_IU',
#  'vitamin_e': 'vitamin_e_mg',
#  'tocopherol_alpha': 'tocopherol_alpha_mg',
#  'vitamin_k': 'vitamin_k_mcg',
#  'calcium': 'calcium_mg',
#  'copper': 'copper_mg',
#  'irom': 'irom_mg',
# ...

# %%
nutrition.rename(columns=mapper, inplace = True)

# %%
nutrition.head()
# Out:
#                 serving_size_g  calories total_fat_g saturated_fat_g  \
# name
# Cornstarch               100 g       381        0.1g             NaN
# Nuts, pecans             100 g       691         72g            6.2g
# Eggplant, raw            100 g        25        0.2g             NaN
# Teff, uncooked           100 g       367        2.4g            0.4g
# Sherbet, orange          100 g       144          2g            1.2g
#
#                 cholesterol_mg sodium_mg choline_mg folate_mcg folic_acid_mcg  \
# name
# Cornstarch                   0   9.00 mg     0.4 mg   0.00 mcg       0.00 mcg
# Nuts, pecans                 0   0.00 mg    40.5 mg  22.00 mcg       0.00 mcg
# Eggplant, raw                0   2.00 mg     6.9 mg  22.00 mcg       0.00 mcg
# Teff, uncooked               0  12.00 mg    13.1 mg          0              0
# Sherbet, orange            1mg  46.00 mg     7.7 mg   4.00 mcg       0.00 mcg
#
#                 niacin_mg  ...    fat_g saturated_fatty_acids_g  \
# ...

# %%
nutrition = nutrition.replace('[a-zA-Z]', '', regex = True).astype(float)

# %%
nutrition.total_fat_g.sum()
# Out:
# 92784.20000000001

# %%
nutrition.head(10)
# Out:
#                     serving_size_g  calories  total_fat_g  saturated_fat_g  \
# name
# Cornstarch                   100.0     381.0          0.1              NaN
# Nuts, pecans                 100.0     691.0         72.0              6.2
# Eggplant, raw                100.0      25.0          0.2              NaN
# Teff, uncooked               100.0     367.0          2.4              0.4
# Sherbet, orange              100.0     144.0          2.0              1.2
# Cauliflower, raw             100.0      25.0          0.3              0.1
# Taro leaves, raw             100.0      42.0          0.7              0.2
# Lamb, raw, ground            100.0     282.0         23.0             10.0
# Cheese, camembert            100.0     300.0         24.0             15.0
# Vegetarian fillets           100.0     290.0         18.0              2.8
#
#                     cholesterol_mg  sodium_mg  choline_mg  folate_mcg  \
# name
# ...

# %% [markdown]
# # Filtering in 2D

# %%
nutrition.shape
# Out:
# (8789, 75)

# %%
nutrition.filter(like = 'octopus', axis = 0)
# Out:
#                                                serving_size_g  calories  \
# name
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
#                                                choline_mg  folate_mcg  \
# name
# Mollusks, raw, common, octopus                       65.0        16.0
# Mollusks, moist heat, cooked, common, octopus        81.0        24.0
#
# ...

# %%
nutrition.filter(like = 'Octopus', axis = 0)
# Out:
#                          serving_size_g  calories  total_fat_g  \
# name
# Octopus (Alaska Native)           100.0      56.0          0.8
#
#                          saturated_fat_g  cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)              0.2            41.0        0.0
#
#                          choline_mg  folate_mcg  folic_acid_mcg  niacin_mg  \
# name
# Octopus (Alaska Native)         0.0         0.0             0.0        2.0
#
#                          ...  fat_g  saturated_fatty_acids_g  \
# name                     ...
# Octopus (Alaska Native)  ...    0.8                      0.2
#
#                          monounsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                            0.0
#
#                          polyunsaturated_fatty_acids_g  \
# name
# Octopus (Alaska Native)                            0.2
#
#                          fatty_acids_total_trans_mg  alcohol_g  ash_g  \
# name
# ...

# %%
nutrition.filter(regex = 'octopus', axis = 0)
# Out:
#                                                serving_size_g  calories  \
# name
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
#                                                choline_mg  folate_mcg  \
# name
# Mollusks, raw, common, octopus                       65.0        16.0
# Mollusks, moist heat, cooked, common, octopus        81.0        24.0
#
# ...

# %%
nutrition.filter(regex = '[Oo]ctopus', axis = 0)
# Out:
#                                                serving_size_g  calories  \
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Octopus (Alaska Native)                                0.8              0.2
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)                                  41.0        0.0
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
# ...

# %%
# Both upper and lower case (1D)
nutrition.filter(regex = '(?i)octopus', axis = 0)
# Out:
#                                                serving_size_g  calories  \
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Octopus (Alaska Native)                                0.8              0.2
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)                                  41.0        0.0
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
# ...

# %%
nutrition.filter(regex = '(?i)octopus', axis = 0)\
         .filter(items = ['serving_size_g', 'cholesterol_mg', 'folate_mcg'], axis = 1)
# Out:
#                                                serving_size_g  cholesterol_mg  \
# name
# Octopus (Alaska Native)                                 100.0            41.0
# Mollusks, raw, common, octopus                          100.0            48.0
# Mollusks, moist heat, cooked, common, octopus           100.0            96.0
#
#                                                folate_mcg
# name
# Octopus (Alaska Native)                               0.0
# Mollusks, raw, common, octopus                       16.0
# Mollusks, moist heat, cooked, common, octopus        24.0

# %% [markdown]
# # Dataframe Sorting

# %%
nutrition.head(3)
# Out:
#                serving_size_g  calories  total_fat_g  saturated_fat_g  \
# name
# Cornstarch              100.0     381.0          0.1              NaN
# Nuts, pecans            100.0     691.0         72.0              6.2
# Eggplant, raw           100.0      25.0          0.2              NaN
#
#                cholesterol_mg  sodium_mg  choline_mg  folate_mcg  \
# name
# Cornstarch                0.0        9.0         0.4         0.0
# Nuts, pecans              0.0        0.0        40.5        22.0
# Eggplant, raw             0.0        2.0         6.9        22.0
#
#                folic_acid_mcg  niacin_mg  ...  fat_g  saturated_fatty_acids_g  \
# name                                      ...
# Cornstarch                0.0      0.000  ...   0.05                    0.009
# Nuts, pecans              0.0      1.167  ...  71.97                    6.180
# Eggplant, raw             0.0      0.649  ...   0.18                    0.034
#
# ...

# %%
nutrition.total_fat_g

# %%
type(nutrition.total_fat_g)

# %%
nutrition.total_fat_g.sort_values()

# %%
nutrition.sort_values(
    by = ['saturated_fat_g'], ascending = False
)

# %%
nutrition.sort_values(
    by = ['saturated_fat_g', 'cholesterol_mg'], ascending = False
).head(5)

# %%
nutrition.sort_values(
    by = ['total_fat_g', 'cholesterol_mg'], ascending = [True, False]
)

# %% [markdown]
# # Using Series between() with Dataframes

# %%
nutrition.calories.head(5)
# Out:
# name
# Cornstarch         381.0
# Nuts, pecans       691.0
# Eggplant, raw       25.0
# Teff, uncooked     367.0
# Sherbet, orange    144.0
# Name: calories, dtype: float64

# %%
nutrition.calories.between(20, 60)
# Out:
# name
# Cornstarch                                                                                            False
# Nuts, pecans                                                                                          False
# Eggplant, raw                                                                                          True
# Teff, uncooked                                                                                        False
# Sherbet, orange                                                                                       False
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    False
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# ...

# %%
nutrition[nutrition.calories.between(20, 60)].shape
# Out:
# (1190, 75)

# %%
nutrition[nutrition.calories.between(20, 60)].sample(5)
# Out:
#                                                     serving_size_g  calories  \
# name
# Beverages, Berry Blend, V8 SPLASH Juice Drinks               100.0      29.0
# Soup, ready-to-serve, chunky, canned, manhattan...           100.0      56.0
# Soup, single brand, condensed, canned, chicken ...           100.0      50.0
# Peaches, solids and liquids, extra light syrup,...           100.0      42.0
# CAMPBELL'S Red and White - Microwaveable Bowls,...           100.0      34.0
#
#                                                     total_fat_g  \
# name
# Beverages, Berry Blend, V8 SPLASH Juice Drinks              0.0
# Soup, ready-to-serve, chunky, canned, manhattan...          1.4
# Soup, single brand, condensed, canned, chicken ...          1.4
# Peaches, solids and liquids, extra light syrup,...          0.1
# CAMPBELL'S Red and White - Microwaveable Bowls,...          0.2
#
#                                                     saturated_fat_g  \
# name
# ...

# %% [markdown]
# # Min , Max and Idx[Min, max]

# %%
nutrition.min()
# Out:
# serving_size_g     100.0
# calories             0.0
# total_fat_g          0.0
# saturated_fat_g      0.1
# cholesterol_mg       0.0
#                    ...
# alcohol_g            0.0
# ash_g                0.0
# caffeine_mg          0.0
# theobromine_mg       0.0
# water_g              0.0
# Length: 75, dtype: float64

# %%
nutrition.min(axis = 1)
# Out:
# name
# Cornstarch                                                                                            0.0
# Nuts, pecans                                                                                          0.0
# Eggplant, raw                                                                                         0.0
# Teff, uncooked                                                                                        0.0
# Sherbet, orange                                                                                       0.0
#                                                                                                      ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    0.0
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    0.0
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    0.0
# ...

# %%
nutrition.max()

# %%
nutrition.max(axis = 1)

# %%
# what food has most potassium

# %%
nutrition.potassium_mg.max()
# Out:
# 16500.0

# %%
nutrition.potassium_mg.idxmax()
# Out:
# 'Leavening agents, cream of tartar'

# %%
nutrition.potassium_mg.sort_values(ascending=False).head(5)
# Out:
# name
# Leavening agents, cream of tartar                      16500.0
# Leavening agents, low-sodium, baking powder            10100.0
# Parsley, freeze-dried                                   6300.0
# Beverages, unsweetened, decaffeinated, instant, tea     6040.0
# Beverages, powder, unsweetened, instant, tea            6040.0
# Name: potassium_mg, dtype: float64

# %%
K_to_NA = (nutrition.potassium_mg).replace(0, 1) / (nutrition.sodium_mg).replace(0, 1)

# %%
K_to_NA.sort_values(ascending = False)
# Out:
# name
# Peanut flour, low fat                                         1358.000000
# Nuts, raw, pistachio nuts                                     1025.000000
# Beverages, reduced calorie, with whitener, instant, coffee     909.000000
# Soybeans, raw, mature seeds                                    898.500000
# Soy meal, raw, defatted                                        830.000000
#                                                                  ...
# Seasoning mix, original, chili, dry                              0.000217
# Salt, table                                                      0.000206
# PACE, Dry Taco Seasoning Mix                                     0.000124
# Seasoning mix, coriander & annatto, sazon, dry                   0.000059
# Leavening agents, baking soda                                    0.000037
# Length: 8789, dtype: float64

# %%
K_to_NA[K_to_NA.sort_values(ascending = False).between(14, 20)].head(5)
# Out:
# name
# Winged bean tuber, raw    16.742857
# McDONALD'S, Side Salad    18.333333
# Babyfood, pear, juice     16.250000
# Brussels sprouts, raw     15.560000
# Spices, garlic powder     19.883333
# dtype: float64

# %% [markdown]
# # nlargest() + nsmallest()

# %%
nutrition.potassium_mg.nlargest(10)
# Out:
# name
# Leavening agents, cream of tartar                         16500.0
# Leavening agents, low-sodium, baking powder               10100.0
# Parsley, freeze-dried                                      6300.0
# Beverages, powder, unsweetened, instant, tea               6040.0
# Beverages, unsweetened, decaffeinated, instant, tea        6040.0
# Spices, dried, chervil                                     4740.0
# Spices, dried, coriander leaf                              4466.0
# Celery flakes, dried                                       4388.0
# Beverages, powder, regular, instant, coffee                3535.0
# Beverages, half the caffeine, regular, instant, coffee     3535.0
# Name: potassium_mg, dtype: float64

# %%
nutrition.potassium_mg.nsmallest(10)
# Out:
# name
# PACE, Picante Sauce       0.0
# Goji berries, dried       0.0
# PACE, Green Taco Sauce    0.0
# Chewing gum, sugarless    0.0
# Oil, soybean lecithin     0.0
# SILK Original Creamer     0.0
# SILK Hazelnut Creamer     0.0
# SILK Peach soy yogurt     0.0
# SILK Plain soy yogurt     0.0
# PACE, Enchilada Sauce     0.0
# Name: potassium_mg, dtype: float64

# %% [markdown]
# # Skill Challenge

# %%
nutrition.head()
# Out:
#                  serving_size_g  calories  total_fat_g  saturated_fat_g  \
# name
# Cornstarch                100.0     381.0          0.1              NaN
# Nuts, pecans              100.0     691.0         72.0              6.2
# Eggplant, raw             100.0      25.0          0.2              NaN
# Teff, uncooked            100.0     367.0          2.4              0.4
# Sherbet, orange           100.0     144.0          2.0              1.2
#
#                  cholesterol_mg  sodium_mg  choline_mg  folate_mcg  \
# name
# Cornstarch                  0.0        9.0         0.4         0.0
# Nuts, pecans                0.0        0.0        40.5        22.0
# Eggplant, raw               0.0        2.0         6.9        22.0
# Teff, uncooked              0.0       12.0        13.1         0.0
# Sherbet, orange             1.0       46.0         7.7         4.0
#
#                  folic_acid_mcg  niacin_mg  ...  fat_g  \
# name                                        ...
# ...

# %%
nutrition.columns

# %%
nutrition.vitamin_b12_mcg.nlargest(10)
# Out:
# name
# Mollusks, moist heat, cooked, mixed species, clam                                   98.89
# Beef, boiled, cooked, variety meats and by-products liver, imported, New Zealand    96.00
# Lamb, raw, liver, variety meats and by-products                                     90.05
# Lamb, pan-fried, cooked, liver, variety meats and by-products                       85.70
# Veal, braised, cooked, liver, variety meats and by-products                         84.60
# Beef, raw, liver, variety meats and by-products, imported, New Zealand              84.50
# Beef, pan-fried, cooked, liver, variety meats and by-products                       83.13
# Lamb, braised, cooked, kidneys, variety meats and by-products                       78.90
# Lamb, braised, cooked, liver, variety meats and by-products                         76.50
# Veal, pan-fried, cooked, liver, variety meats and by-products                       72.50
# Name: vitamin_b12_mcg, dtype: float64

# %%
nutrition.nlargest(10, 'vitamin_b12_mcg')
# Out:
#                                                     serving_size_g  calories  \
# name
# Mollusks, moist heat, cooked, mixed species, clam            100.0     148.0
# Beef, boiled, cooked, variety meats and by-prod...           100.0     150.0
# Lamb, raw, liver, variety meats and by-products              100.0     139.0
# Lamb, pan-fried, cooked, liver, variety meats a...           100.0     238.0
# Veal, braised, cooked, liver, variety meats and...           100.0     192.0
# Beef, raw, liver, variety meats and by-products...           100.0     133.0
# Beef, pan-fried, cooked, liver, variety meats a...           100.0     175.0
# Lamb, braised, cooked, kidneys, variety meats a...           100.0     137.0
# Lamb, braised, cooked, liver, variety meats and...           100.0     220.0
# Veal, pan-fried, cooked, liver, variety meats a...           100.0     193.0
#
#                                                     total_fat_g  \
# name
# ...

# %%
nutrition.filter(regex = '(?i)eggplant', axis = 0)
# Out:
#                                                  serving_size_g  calories  \
# name
# Eggplant, raw                                             100.0      25.0
# Eggplant, pickled                                         100.0      49.0
# Eggplant, with salt, drained, boiled, cooked              100.0      33.0
# Eggplant, without salt, drained, boiled, cooked           100.0      35.0
#
#                                                  total_fat_g  saturated_fat_g  \
# name
# Eggplant, raw                                            0.2              NaN
# Eggplant, pickled                                        0.7              0.1
# Eggplant, with salt, drained, boiled, cooked             0.2              NaN
# Eggplant, without salt, drained, boiled, cooked          0.2              NaN
#
#                                                  cholesterol_mg  sodium_mg  \
# name
# Eggplant, raw                                               0.0        2.0
# ...

# %%
nutrition.filter(regex = '(?i)eggplant', axis = 0).nlargest(1, 'sodium_mg')
# Out:
#                    serving_size_g  calories  total_fat_g  saturated_fat_g  \
# name
# Eggplant, pickled           100.0      49.0          0.7              0.1
#
#                    cholesterol_mg  sodium_mg  choline_mg  folate_mcg  \
# name
# Eggplant, pickled             0.0     1674.0        11.9        20.0
#
#                    folic_acid_mcg  niacin_mg  ...  fat_g  \
# name                                          ...
# Eggplant, pickled             0.0       0.66  ...    0.7
#
#                    saturated_fatty_acids_g  monounsaturated_fatty_acids_g  \
# name
# Eggplant, pickled                     0.14                          0.063
#
#                    polyunsaturated_fatty_acids_g  fatty_acids_total_trans_mg  \
# name
# Eggplant, pickled                          0.294                         0.0
#
#                    alcohol_g  ash_g  caffeine_mg  theobromine_mg  water_g
# name
# Eggplant, pickled        0.0   1.73          0.0             0.0     86.9
#
# ...

# %%
nutrition.sample(axis = 0, n = 4).sample(axis = 1, n = 2)
# Out:
#                                                     valine_g  vitamin_d_IU
# name
# Beverages, contains caffeine, pepper-type, carb...      0.00           0.0
# MARTHA WHITE FOODS, dry, Martha White's Chewy F...      0.00           0.0
# Turkey, roasted, cooked, with added solution, m...      1.11           6.0
# KASHI, Sea Salt, Pita Crisps, TLC                       0.00           0.0

# %%
# Challenge 2

# %%
challenge2_df = nutrition.dropna(how = 'any', axis = 0)

# %%
nutrition.shape[0]
# Out:
# 8789

# %%
challenge2_df.shape[0]
challenge2_df
# Out:
#                                                     serving_size_g  calories  \
# name
# Nuts, pecans                                                 100.0     691.0
# Teff, uncooked                                               100.0     367.0
# Sherbet, orange                                              100.0     144.0
# Cauliflower, raw                                             100.0      25.0
# Taro leaves, raw                                             100.0      42.0
# ...                                                            ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     125.0
# Lamb, cooked, separable lean only, composite of...           100.0     206.0
# Lamb, raw, separable lean and fat, composite of...           100.0     277.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
#
# ...

# %%
#vitamin_c_mg
challenge2_df[challenge2_df.vitamin_c_mg.between(20, 40)].nsmallest(5, columns = 'calories')
# Out:
#                                                     serving_size_g  calories  \
# name
# Asparagus, with salt, drained, boiled, cooked, ...           100.0      18.0
# Asparagus, without salt, drained, boiled, cooke...           100.0      18.0
# Turnip greens, without salt, drained, boiled, c...           100.0      20.0
# Turnip greens, with salt, drained, boiled, cooked            100.0      20.0
# Borage, raw                                                  100.0      21.0
#
#                                                     total_fat_g  \
# name
# Asparagus, with salt, drained, boiled, cooked, ...          0.4
# Asparagus, without salt, drained, boiled, cooke...          0.4
# Turnip greens, without salt, drained, boiled, c...          0.2
# Turnip greens, with salt, drained, boiled, cooked           0.2
# Borage, raw                                                 0.7
#
#                                                     saturated_fat_g  \
# name
# ...

# %%
challenge2_df[challenge2_df.vitamin_c_mg.between(20, 40)].calories.nsmallest(5)
# Out:
# name
# Asparagus, with salt, drained, boiled, cooked, frozen       18.0
# Asparagus, without salt, drained, boiled, cooked, frozen    18.0
# Turnip greens, without salt, drained, boiled, cooked        20.0
# Turnip greens, with salt, drained, boiled, cooked           20.0
# Borage, raw                                                 21.0
# Name: calories, dtype: float64

# %%
mean = challenge2_df.vitamin_c_mg.mean()

# %%
mean
# Out:
# 5.553368523406029

# %%
std2 = mean + challenge2_df.vitamin_c_mg.std() * 2

# %%
std3 = mean + challenge2_df.vitamin_c_mg.std() * 3

# %%
print(mean, std2, std3)
# Out:
# 5.553368523406029 97.76213896818041 143.8665241905676

# %%
challenge2_df[challenge2_df.vitamin_c_mg.between(std2, std3)].shape
# Out:
# (17, 75)
