# %%
import pandas as pd

# %%
pd.read_csv('/content/sample_data/drinks.csv')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            NaN              NaN            NaN
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              NaN           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0              1.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             NaN
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
alcohol = pd.read_csv('/content/sample_data/drinks.csv', usecols = ['country', 'wine_servings'], index_col = 'country')

# %%
alcohol.head()
# Out:
#              wine_servings
# country
# Afghanistan            NaN
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0

# %%
type(alcohol)
# Out:
# pandas.core.frame.DataFrame

# %%
alcohol.size
# Out:
# 193

# %%
alcohol.values
# Out:
# array([[ nan],
#        [ 54.],
#        [ 14.],
#        [312.],
#        [ 45.],
#        [ 45.],
#        [221.],
#        [ 11.],
#        [212.],
#        [191.],
#        [  5.],
#        [ 51.],
#        [  7.],
#        [ nan],
#        [ 36.],
#        [ 42.],
#        [212.],
#        [  8.],
#        [ 13.],
#        [ nan],
#        [  8.],
#        [  8.],
#        [ 35.],
#        [ 16.],
#        [  1.],
#        [ 94.],
#        [  7.],
#        [ nan],
#        [  7.],
#        [ 16.],
#        [  1.],
#        [  4.],
#        [  1.],
#        [  1.],
#        [  1.],
#        [172.],
#        [  8.],
#        [  3.],
#        [  1.],
#        [  9.],
#        [ 74.],
#        [ 11.],
#        [254.],
#        [  5.],
#        [113.],
#        [134.],
#        [ nan],
#        [  1.],
#        [278.],
#        [  3.],
#        [ 26.],
#        [  9.],
#        [  3.],
#        [  1.],
#        [  2.],
#        [233.],
#        [ nan],
#        [ 59.],
# ...

# %%
alcohol.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
alcohol.values.size == alcohol.index.size
# Out:
# True

# %%
alcohol.size
# Out:
# 193

# %%
alcohol.shape
# Out:
# (193, 1)

# %%
alcohol.size == alcohol.shape[0]
# Out:
# True

# %%
len(alcohol)
# Out:
# 193

# %% [markdown]
# Unique Values and Series Monotonicity

# %%
type(alcohol)
# Out:
# pandas.core.frame.DataFrame

# %%
alcohol_series = alcohol.iloc[:,0]

# %%
alcohol_series
# Out:
# country
# Afghanistan      NaN
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol_series.is_unique
# Out:
# False

# %%
alcohol_series.head().is_unique
# Out:
# True

# %%
alcohol_series.nunique(dropna = False)
# Out:
# 72

# %%
pd.Series([1, 2, 3, 4, 5, 0]).is_monotonic  # increasing or decreasing.alcohol
# Out:
# <ipython-input-20-02016cbf2ae4>:1: FutureWarning: is_monotonic is deprecated and will be removed in a future version. Use is_monotonic_increasing instead.
#   pd.Series([1, 2, 3, 4, 5, 0]).is_monotonic  # increasing or decreasing.alcohol
# False

# %% [markdown]
# Count () -- Return the number of not NA/ null observations in the series

# %%
alcohol_series.count()
# Out:
# 162

# %%
alcohol_series.size
# Out:
# 193

# %%
alcohol_series.hasnans
# Out:
# True

# %%
nan = alcohol_series.size - alcohol_series.count()

# %%
nan
# Out:
# 31

# %% [markdown]
# Accessing and counting NA's

# %%
alcohol_series.isnull()
# Out:
# country
# Afghanistan     True
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Venezuela      False
# Vietnam        False
# Yemen           True
# Zambia         False
# Zimbabwe       False
# Name: wine_servings, Length: 193, dtype: bool

# %%
alcohol_series
# Out:
# country
# Afghanistan      NaN
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol_series[alcohol_series.isnull()]
# Out:
# country
# Afghanistan        NaN
# Bangladesh         NaN
# Bhutan             NaN
# Burundi            NaN
# North Korea        NaN
# Eritrea            NaN
# Ethiopia           NaN
# India              NaN
# Indonesia          NaN
# Iran               NaN
# Iraq               NaN
# Kuwait             NaN
# Lesotho            NaN
# Libya              NaN
# Malaysia           NaN
# Maldives           NaN
# Marshall Islands   NaN
# Mauritania         NaN
# Monaco             NaN
# Myanmar            NaN
# Nepal              NaN
# Pakistan           NaN
# Rwanda             NaN
# San Marino         NaN
# Saudi Arabia       NaN
# Somalia            NaN
# Sri Lanka          NaN
# Sudan              NaN
# Tajikistan         NaN
# Uganda             NaN
# Yemen              NaN
# Name: wine_servings, dtype: float64

# %%
alcohol_series[alcohol_series.isnull()].index
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'Burundi', 'North Korea',
#        'Eritrea', 'Ethiopia', 'India', 'Indonesia', 'Iran', 'Iraq', 'Kuwait',
#        'Lesotho', 'Libya', 'Malaysia', 'Maldives', 'Marshall Islands',
#        'Mauritania', 'Monaco', 'Myanmar', 'Nepal', 'Pakistan', 'Rwanda',
#        'San Marino', 'Saudi Arabia', 'Somalia', 'Sri Lanka', 'Sudan',
#        'Tajikistan', 'Uganda', 'Yemen'],
#       dtype='object', name='country')

# %%
list(alcohol_series[alcohol_series.isnull()].index)
# Out:
# ['Afghanistan',
#  'Bangladesh',
#  'Bhutan',
#  'Burundi',
#  'North Korea',
#  'Eritrea',
#  'Ethiopia',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Kuwait',
#  'Lesotho',
#  'Libya',
#  'Malaysia',
#  'Maldives',
#  'Marshall Islands',
#  'Mauritania',
#  'Monaco',
#  'Myanmar',
#  'Nepal',
#  'Pakistan',
#  'Rwanda',
#  'San Marino',
#  'Saudi Arabia',
#  'Somalia',
#  'Sri Lanka',
#  'Sudan',
#  'Tajikistan',
#  'Uganda',
#  'Yemen']

# %%
len(list(alcohol_series[alcohol_series.isnull()].index))
# Out:
# 31

# %%
alcohol_series.isnull().sum()
# Out:
# 31

# %%
alcohol.isnull().sum()
# Out:
# wine_servings    31
# dtype: int64

# %% [markdown]
# Another approach

# %%
import numpy as np

# %%
np_series = pd.Series(alcohol_series.head())

# %%
np_series
# Out:
# country
# Afghanistan      NaN
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
# Name: wine_servings, dtype: float64

# %%
np.isnan(np_series)
# Out:
# country
# Afghanistan     True
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
# Name: wine_servings, dtype: bool

# %%
alcohol_series[np.isnan].size
# Out:
# 31

# %% [markdown]
# The other side : notnull() and notna()

# %%
alcohol_series.notnull()
# Out:
# country
# Afghanistan    False
# Albania         True
# Algeria         True
# Andorra         True
# Angola          True
#                ...
# Venezuela       True
# Vietnam         True
# Yemen          False
# Zambia          True
# Zimbabwe        True
# Name: wine_servings, Length: 193, dtype: bool

# %%
alcohol_series.loc[alcohol_series.notnull()]
# Out:
# country
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
#                      ...
# Vanuatu               11.0
# Venezuela              3.0
# Vietnam                1.0
# Zambia                 4.0
# Zimbabwe               4.0
# Name: wine_servings, Length: 162, dtype: float64

# %%
alcohol_series.notnull().sum()
# Out:
# 162

# %%
alcohol_series.count()
# Out:
# 162

# %% [markdown]
# Skill Test

# %%
alcohol_series
# Out:
# country
# Afghanistan      NaN
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
wine_servings = alcohol_series[alcohol_series.notnull()]

# %%
wine_servings
# Out:
# country
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
#                      ...
# Vanuatu               11.0
# Venezuela              3.0
# Vietnam                1.0
# Zambia                 4.0
# Zimbabwe               4.0
# Name: wine_servings, Length: 162, dtype: float64

# %%
wine_servings.size
# Out:
# 162

# %%
total_wine_consumed_1 = sum(wine_servings[0:len(wine_servings)])

# %%
total_wine_consumed_2 = wine_servings.sum()

# %%
total_wine_consumed_1, total_wine_consumed_2
# Out:
# (8221.0, 8221.0)

# %%
total_less_than_100 = 0
for i in range(0, wine_servings.size):
  if wine_servings[i] < 100:
    total_less_than_100 += wine_servings[i]

# %%
total_less_than_100
# Out:
# 2416.0

# %%
wine_servings < 100
# Out:
# country
# Albania               True
# Algeria               True
# Andorra              False
# Angola                True
# Antigua & Barbuda     True
#                      ...
# Vanuatu               True
# Venezuela             True
# Vietnam               True
# Zambia                True
# Zimbabwe              True
# Name: wine_servings, Length: 162, dtype: bool

# %%
wine_servings[wine_servings < 100].sum()
# Out:
# 2416.0

# %% [markdown]
# Dropping and Filling NA's

# %%
alcohol.dropna()
# Out:
#                    wine_servings
# country
# Albania                     54.0
# Algeria                     14.0
# Andorra                    312.0
# Angola                      45.0
# Antigua & Barbuda           45.0
# ...                          ...
# Vanuatu                     11.0
# Venezuela                    3.0
# Vietnam                      1.0
# Zambia                       4.0
# Zimbabwe                     4.0
#
# [162 rows x 1 columns]

# %%
alcohol_series.dropna()
# Out:
# country
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
#                      ...
# Vanuatu               11.0
# Venezuela              3.0
# Vietnam                1.0
# Zambia                 4.0
# Zimbabwe               4.0
# Name: wine_servings, Length: 162, dtype: float64

# %%
alcohol_series.dropna().size
# Out:
# 162

# %%
alcohol_notnulls = alcohol_series.dropna()

# %%
alcohol_notnulls
# Out:
# country
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
#                      ...
# Vanuatu               11.0
# Venezuela              3.0
# Vietnam                1.0
# Zambia                 4.0
# Zimbabwe               4.0
# Name: wine_servings, Length: 162, dtype: float64

# %%
alcohol_series.fillna(100, inplace = False)
# Out:
# country
# Afghanistan    100.0
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen          100.0
# Zambia           4.0
# Zimbabwe         4.0
# Name: wine_servings, Length: 193, dtype: float64

# %% [markdown]
# Descriptive Statistics

# %%
# Average of the wine consumption
wine_servings.sum() / wine_servings.count()
# Out:
# 50.74691358024691

# %%
wine_servings.mean()
# Out:
# 50.74691358024691

# %%
wine_servings.median()
# Out:
# 11.5

# %%
wine_servings.quantile(0.5)
# Out:
# 11.5

# %% [markdown]
# Describe ()

# %%
alcohol_series.describe()
# Out:
# count    162.000000
# mean      50.746914
# std       76.134917
# min        1.000000
# 25%        3.000000
# 50%       11.500000
# 75%       61.250000
# max      339.000000
# Name: wine_servings, dtype: float64

# %%
alcohol_series.describe()
# Out:
# count    162.000000
# mean      50.746914
# std       76.134917
# min        1.000000
# 25%        3.000000
# 50%       11.500000
# 75%       61.250000
# max      339.000000
# Name: wine_servings, dtype: float64

# %%
#Mode : highest frequency

alcohol_series.mode()
# Out:
# 0    1.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series == 1
# Out:
# country
# Afghanistan    False
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Venezuela      False
# Vietnam         True
# Yemen          False
# Zambia         False
# Zimbabwe       False
# Name: wine_servings, Length: 193, dtype: bool

# %%
alcohol_series[alcohol_series == 1]
# Out:
# country
# Brunei                      1.0
# Cambodia                    1.0
# Canada                      1.0
# Central African Republic    1.0
# Chad                        1.0
# Comoros                     1.0
# DR Congo                    1.0
# Egypt                       1.0
# Fiji                        1.0
# Gambia                      1.0
# Ghana                       1.0
# Guyana                      1.0
# Haiti                       1.0
# Jordan                      1.0
# Kiribati                    1.0
# Malawi                      1.0
# Mali                        1.0
# Morocco                     1.0
# Namibia                     1.0
# Nicaragua                   1.0
# Niger                       1.0
# Oman                        1.0
# Papua New Guinea            1.0
# Philippines                 1.0
# Solomon Islands             1.0
# Thailand                    1.0
# Tanzania                    1.0
# Vietnam                     1.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series[alcohol_series == 1].size
# Out:
# 28

# %%
#value count : Count the number of occurances for each unique values
#              Displays a sorted series
"""
ser.value_counts(sort = True, ascending = True, dropna = False)
"""
# Out:
# '\nser.value_counts(sort = True, ascending = True, dropna = False)\n'

# %%
alcohol.value_counts()
# Out:
# wine_servings
# 1.0              28
# 2.0              10
# 7.0               9
# 8.0               7
# 9.0               6
#                  ..
# 86.0              1
# 94.0              1
# 97.0              1
# 112.0             1
# 339.0             1
# Length: 71, dtype: int64

# %%
 alcohol_series.value_counts(normalize = True)
 # alcohol_series.iloc[0] / alcohol_series.count()
# Out:
# 1.0      0.172840
# 2.0      0.061728
# 7.0      0.055556
# 8.0      0.043210
# 5.0      0.037037
#            ...
# 218.0    0.006173
# 185.0    0.006173
# 78.0     0.006173
# 165.0    0.006173
# 22.0     0.006173
# Name: wine_servings, Length: 71, dtype: float64

# %%
alcohol_series.value_counts().iloc[0] / alcohol_series.count()
# Out:
# 0.1728395061728395

# %% [markdown]
# idxmax() and idxmin()

# %%
alcohol.max()
# Out:
# wine_servings    339.0
# dtype: float64

# %%
alcohol_series[alcohol_series == alcohol_series.max()]
# Out:
# country
# Portugal    339.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series[alcohol_series == alcohol_series.max()].index
# Out:
# Index(['Portugal'], dtype='object', name='country')

# %%
alcohol_series[alcohol_series == alcohol_series.max()].index[0]
# Out:
# 'Portugal'

# %%
alcohol_series.idxmax()
# Out:
# 'Portugal'

# %%
alcohol_series.idxmin()
# Out:
# 'Brunei'

# %%
alcohol_series[alcohol_series == alcohol_series.min()]
# Out:
# country
# Brunei                      1.0
# Cambodia                    1.0
# Canada                      1.0
# Central African Republic    1.0
# Chad                        1.0
# Comoros                     1.0
# DR Congo                    1.0
# Egypt                       1.0
# Fiji                        1.0
# Gambia                      1.0
# Ghana                       1.0
# Guyana                      1.0
# Haiti                       1.0
# Jordan                      1.0
# Kiribati                    1.0
# Malawi                      1.0
# Mali                        1.0
# Morocco                     1.0
# Namibia                     1.0
# Nicaragua                   1.0
# Niger                       1.0
# Oman                        1.0
# Papua New Guinea            1.0
# Philippines                 1.0
# Solomon Islands             1.0
# Thailand                    1.0
# Tanzania                    1.0
# Vietnam                     1.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series[alcohol_series.idxmax()]
# Out:
# 339.0

# %% [markdown]
# Sort with values

# %%
alcohol_series.sort_values()
# Out:
# country
# Thailand           1.0
# Solomon Islands    1.0
# Brunei             1.0
# Haiti              1.0
# Cambodia           1.0
#                   ...
# Sri Lanka          NaN
# Sudan              NaN
# Tajikistan         NaN
# Uganda             NaN
# Yemen              NaN
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol_series.sort_values(ascending = False)
# Out:
# country
# Portugal      339.0
# Andorra       312.0
# Denmark       278.0
# Slovenia      276.0
# Luxembourg    271.0
#               ...
# Sri Lanka       NaN
# Sudan           NaN
# Tajikistan      NaN
# Uganda          NaN
# Yemen           NaN
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol_series.sort_values(ascending = False, na_position = 'last')
# Out:
# country
# Portugal      339.0
# Andorra       312.0
# Denmark       278.0
# Slovenia      276.0
# Luxembourg    271.0
#               ...
# Sri Lanka       NaN
# Sudan           NaN
# Tajikistan      NaN
# Uganda          NaN
# Yemen           NaN
# Name: wine_servings, Length: 193, dtype: float64

# %% [markdown]
# nlargeest() and nsmallest()

# %%
alcohol_series.sort_values(ascending = False)[:10]
# Out:
# country
# Portugal             339.0
# Andorra              312.0
# Denmark              278.0
# Slovenia             276.0
# Luxembourg           271.0
# Croatia              254.0
# Italy                237.0
# Equatorial Guinea    233.0
# Argentina            221.0
# Greece               218.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series.nlargest(n = 10)
# Out:
# country
# Portugal             339.0
# Andorra              312.0
# Denmark              278.0
# Slovenia             276.0
# Luxembourg           271.0
# Croatia              254.0
# Italy                237.0
# Equatorial Guinea    233.0
# Argentina            221.0
# Greece               218.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series.nsmallest(n = 10)
# Out:
# country
# Brunei                      1.0
# Cambodia                    1.0
# Canada                      1.0
# Central African Republic    1.0
# Chad                        1.0
# Comoros                     1.0
# DR Congo                    1.0
# Egypt                       1.0
# Fiji                        1.0
# Gambia                      1.0
# Name: wine_servings, dtype: float64

# %% [markdown]
# Sorting with sort_index()

# %%
alcohol_series.head(10)
# Out:
# country
# Afghanistan            NaN
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
# Argentina            221.0
# Armenia               11.0
# Australia            212.0
# Austria              191.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series = alcohol.iloc[:,0]

# %% [markdown]
# Skill Challenge

# %%
alcohol_series.head(20)
# Out:
# country
# Afghanistan            NaN
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
# Argentina            221.0
# Armenia               11.0
# Australia            212.0
# Austria              191.0
# Azerbaijan             5.0
# Bahamas               51.0
# Bahrain                7.0
# Bangladesh             NaN
# Barbados              36.0
# Belarus               42.0
# Belgium              212.0
# Belize                 8.0
# Benin                 13.0
# Bhutan                 NaN
# Name: wine_servings, dtype: float64

# %%
alcohol
# Out:
#              wine_servings
# country
# Afghanistan            NaN
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# ...                    ...
# Venezuela              3.0
# Vietnam                1.0
# Yemen                  NaN
# Zambia                 4.0
# Zimbabwe               4.0
#
# [193 rows x 1 columns]

# %%
fifty_plus = alcohol_series[alcohol_series > 50]

# %%
fifty_plus.count()
# Out:
# 48

# %%
fifty_plus.sort_values().head(20)
# Out:
# country
# Seychelles             51.0
# Bahamas                51.0
# Albania                54.0
# Poland                 56.0
# Lithuania              56.0
# Gabon                  59.0
# Estonia                59.0
# Latvia                 62.0
# St. Lucia              71.0
# Russian Federation     73.0
# Paraguay               74.0
# Cook Islands           74.0
# Iceland                78.0
# South Africa           81.0
# USA                    84.0
# Macedonia              86.0
# Bulgaria               94.0
# Finland                97.0
# Spain                 112.0
# Cyprus                113.0
# Name: wine_servings, dtype: float64

# %% [markdown]
# Series Arithmetic and fill_value()

# %%
more_drinks = pd.Series({'Albania' : 6, 'Algeria' : 10})

# %%
alcohol_series.add(more_drinks, fill_value = 0)
# Out:
# Afghanistan      NaN
# Albania         60.0
# Algeria         24.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Length: 193, dtype: float64

# %%
alcohol_series.subtract(more_drinks, fill_value = 0)
# Out:
# Afghanistan      NaN
# Albania         48.0
# Algeria          4.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Length: 193, dtype: float64

# %%
alcohol_series.divide(more_drinks, fill_value = 1)
# Out:
# Afghanistan      NaN
# Albania          9.0
# Algeria          1.4
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Length: 193, dtype: float64

# %%
alcohol_series.multiply(more_drinks, fill_value = 1)
# Out:
# Afghanistan      NaN
# Albania        324.0
# Algeria        140.0
# Andorra        312.0
# Angola          45.0
#                ...
# Venezuela        3.0
# Vietnam          1.0
# Yemen            NaN
# Zambia           4.0
# Zimbabwe         4.0
# Length: 193, dtype: float64

# %% [markdown]
# Calculating Variance and Standard Deviation

# %%
alcohol_series.var()
# Out:
# 5796.5256115328575

# %%
alcohol_series.std()
# Out:
# 76.13491716376171

# %% [markdown]
# Cumulative Operations

# %%
alcohol_series.sum()
# Out:
# 8221.0

# %%
alcohol_series.cumsum(skipna=True) # by default
# Out:
# country
# Afghanistan       NaN
# Albania          54.0
# Algeria          68.0
# Andorra         380.0
# Angola          425.0
#                 ...
# Venezuela      8212.0
# Vietnam        8213.0
# Yemen             NaN
# Zambia         8217.0
# Zimbabwe       8221.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol_series.prod()
# Out:
# 3.427611505218281e+183

# %%
alcohol_series.cumprod()
# Out:
# country
# Afghanistan              NaN
# Albania         5.400000e+01
# Algeria         7.560000e+02
# Andorra         2.358720e+05
# Angola          1.061424e+07
#                    ...
# Venezuela      2.142257e+182
# Vietnam        2.142257e+182
# Yemen                    NaN
# Zambia         8.569029e+182
# Zimbabwe       3.427612e+183
# Name: wine_servings, Length: 193, dtype: float64

# %% [markdown]
# Pairwise Differences with Diff()

# %%
alcohol_series.head()
# Out:
# country
# Afghanistan      NaN
# Albania         54.0
# Algeria         14.0
# Andorra        312.0
# Angola          45.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series.diff()
# Out:
# country
# Afghanistan      NaN
# Albania          NaN
# Algeria        -40.0
# Andorra        298.0
# Angola        -267.0
#                ...
# Venezuela       -8.0
# Vietnam         -2.0
# Yemen            NaN
# Zambia           NaN
# Zimbabwe         0.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol_series.diff(periods=2).head(10)
# Out:
# country
# Afghanistan            NaN
# Albania                NaN
# Algeria                NaN
# Andorra              258.0
# Angola                31.0
# Antigua & Barbuda   -267.0
# Argentina            176.0
# Armenia              -34.0
# Australia             -9.0
# Austria              180.0
# Name: wine_servings, dtype: float64

# %% [markdown]
# Series Iteration

# %%
mini_ser = alcohol_series[:20]

# %%
mini_ser
# Out:
# country
# Afghanistan            NaN
# Albania               54.0
# Algeria               14.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
# Argentina            221.0
# Armenia               11.0
# Australia            212.0
# Austria              191.0
# Azerbaijan             5.0
# Bahamas               51.0
# Bahrain                7.0
# Bangladesh             NaN
# Barbados              36.0
# Belarus               42.0
# Belgium              212.0
# Belize                 8.0
# Benin                 13.0
# Bhutan                 NaN
# Name: wine_servings, dtype: float64

# %%
for row in mini_ser:
  print(row)
# Out:
# nan
# 54.0
# 14.0
# 312.0
# 45.0
# 45.0
# 221.0
# 11.0
# 212.0
# 191.0
# 5.0
# 51.0
# 7.0
# nan
# 36.0
# 42.0
# 212.0
# 8.0
# 13.0
# nan

# %%
for row in mini_ser.index:
  print(row)
# Out:
# Afghanistan
# Albania
# Algeria
# Andorra
# Angola
# Antigua & Barbuda
# Argentina
# Armenia
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bhutan

# %%
for row in mini_ser.index:
  print(row, mini_ser[row])
# Out:
# Afghanistan nan
# Albania 54.0
# Algeria 14.0
# Andorra 312.0
# Angola 45.0
# Antigua & Barbuda 45.0
# Argentina 221.0
# Armenia 11.0
# Australia 212.0
# Austria 191.0
# Azerbaijan 5.0
# Bahamas 51.0
# Bahrain 7.0
# Bangladesh nan
# Barbados 36.0
# Belarus 42.0
# Belgium 212.0
# Belize 8.0
# Benin 13.0
# Bhutan nan

# %%
for row in mini_ser.items():
  print(row)
# Out:
# ('Afghanistan', nan)
# ('Albania', 54.0)
# ('Algeria', 14.0)
# ('Andorra', 312.0)
# ('Angola', 45.0)
# ('Antigua & Barbuda', 45.0)
# ('Argentina', 221.0)
# ('Armenia', 11.0)
# ('Australia', 212.0)
# ('Austria', 191.0)
# ('Azerbaijan', 5.0)
# ('Bahamas', 51.0)
# ('Bahrain', 7.0)
# ('Bangladesh', nan)
# ('Barbados', 36.0)
# ('Belarus', 42.0)
# ('Belgium', 212.0)
# ('Belize', 8.0)
# ('Benin', 13.0)
# ('Bhutan', nan)

# %% [markdown]
# Filtering : filter() where(), and Mask()

# %%
for i in alcohol_series.items():
  if i[0][0] == 'V':
    print(i)
# Out:
# ('Vanuatu', 11.0)
# ('Venezuela', 3.0)
# ('Vietnam', 1.0)

# %%
for i in alcohol_series.items():
  if 'stan' in i[0]:
    print(i)
# Out:
# ('Afghanistan', nan)
# ('Kazakhstan', 12.0)
# ('Kyrgyzstan', 6.0)
# ('Pakistan', nan)
# ('Tajikistan', nan)
# ('Turkmenistan', 32.0)
# ('Uzbekistan', 8.0)

# %%
# Filter Function
alcohol_series.filter(regex = '^V')
# Out:
# country
# Vanuatu      11.0
# Venezuela     3.0
# Vietnam       1.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series.filter(like = 'stan')
# Out:
# country
# Afghanistan      NaN
# Kazakhstan      12.0
# Kyrgyzstan       6.0
# Pakistan         NaN
# Tajikistan       NaN
# Turkmenistan    32.0
# Uzbekistan       8.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series[alcohol_series > 200]
# Out:
# country
# Andorra              312.0
# Argentina            221.0
# Australia            212.0
# Belgium              212.0
# Croatia              254.0
# Denmark              278.0
# Equatorial Guinea    233.0
# Greece               218.0
# Italy                237.0
# Luxembourg           271.0
# Portugal             339.0
# Slovenia             276.0
# Name: wine_servings, dtype: float64

# %%
# Where() Method

# %%
alcohol_series.where(lambda x: x>200).dropna()
# Out:
# country
# Andorra              312.0
# Argentina            221.0
# Australia            212.0
# Belgium              212.0
# Croatia              254.0
# Denmark              278.0
# Equatorial Guinea    233.0
# Greece               218.0
# Italy                237.0
# Luxembourg           271.0
# Portugal             339.0
# Slovenia             276.0
# Name: wine_servings, dtype: float64

# %%
alcohol_series.where(lambda x: x<200).dropna()
# Out:
# country
# Albania              54.0
# Algeria              14.0
# Angola               45.0
# Antigua & Barbuda    45.0
# Armenia              11.0
#                      ...
# Vanuatu              11.0
# Venezuela             3.0
# Vietnam               1.0
# Zambia                4.0
# Zimbabwe              4.0
# Name: wine_servings, Length: 150, dtype: float64

# %%
# Mask Method

# %%
alcohol_series.mask(lambda x: x<200).dropna()
# Out:
# country
# Andorra              312.0
# Argentina            221.0
# Australia            212.0
# Belgium              212.0
# Croatia              254.0
# Denmark              278.0
# Equatorial Guinea    233.0
# Greece               218.0
# Italy                237.0
# Luxembourg           271.0
# Portugal             339.0
# Slovenia             276.0
# Name: wine_servings, dtype: float64

# %% [markdown]
# Transforming with update(), apply(), and Map()

# %%
alcohol_series.update(pd.Series(data = [200, 20], index = ['Albania', 'Algeria']))

# %%
alcohol_series.head(20)
# Out:
# country
# Afghanistan            NaN
# Albania              200.0
# Algeria               20.0
# Andorra              312.0
# Angola                45.0
# Antigua & Barbuda     45.0
# Argentina            221.0
# Armenia               11.0
# Australia            212.0
# Austria              191.0
# Azerbaijan             5.0
# Bahamas               51.0
# Bahrain                7.0
# Bangladesh             NaN
# Barbados              36.0
# Belarus               42.0
# Belgium              212.0
# Belize                 8.0
# Benin                 13.0
# Bhutan                 NaN
# Name: wine_servings, dtype: float64

# %%
# the Apply() method

# %%
alcohol_series.apply(lambda x : x ** 2)
# Out:
# country
# Afghanistan        NaN
# Albania        40000.0
# Algeria          400.0
# Andorra        97344.0
# Angola          2025.0
#                 ...
# Venezuela          9.0
# Vietnam            1.0
# Yemen              NaN
# Zambia            16.0
# Zimbabwe          16.0
# Name: wine_servings, Length: 193, dtype: float64

# %%
alcohol_series.apply(np.square)
# Out:
# country
# Afghanistan        NaN
# Albania        40000.0
# Algeria          400.0
# Andorra        97344.0
# Angola          2025.0
#                 ...
# Venezuela          9.0
# Vietnam            1.0
# Yemen              NaN
# Zambia            16.0
# Zimbabwe          16.0
# Name: wine_servings, Length: 193, dtype: float64

# %% [markdown]
# Skill Challenge

# %%
beer_servings = pd.read_csv('/content/sample_data/drinks.csv',  usecols = ['country', 'beer_servings'], index_col = 'country')

# %%
beer_servings
# Out:
#              beer_servings
# country
# Afghanistan            NaN
# Albania               89.0
# Algeria               25.0
# Andorra              245.0
# Angola               217.0
# ...                    ...
# Venezuela            333.0
# Vietnam              111.0
# Yemen                  6.0
# Zambia                32.0
# Zimbabwe              64.0
#
# [193 rows x 1 columns]

# %%
beers = pd.Series(beer_servings.iloc[:, 0])

# %%
beers
# Out:
# country
# Afghanistan      NaN
# Albania         89.0
# Algeria         25.0
# Andorra        245.0
# Angola         217.0
#                ...
# Venezuela      333.0
# Vietnam        111.0
# Yemen            6.0
# Zambia          32.0
# Zimbabwe        64.0
# Name: beer_servings, Length: 193, dtype: float64

# %%
beers.describe()
# Out:
# count    178.000000
# mean     102.870787
# std      100.645713
# min        1.000000
# 25%       21.000000
# 50%       60.000000
# 75%      172.500000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
beers.mean()
# Out:
# 102.87078651685393

# %%
beers.std()
# Out:
# 100.6457126793478

# %%
beers.median()
# Out:
# 60.0
